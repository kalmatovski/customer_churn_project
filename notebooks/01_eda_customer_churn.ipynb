# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/churn.csv")
df.shape
# Out:
# (7043, 21)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")

# %%
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
display(df["Churn"].value_counts())
display(df["Churn"].value_counts(normalize=True))
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64
# Churn
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64

# %%
df["Churn"].value_counts().plot(kind="bar")
plt.title("Churn Distributuion")
plt.xlabel("Churn")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Block 1 Notes
#
# - Dataset has 7043 rows and 21 columns.
# - Target column is `Churn`.
# - `Churn = Yes` means the customer left the company.
# - `Churn = No` means the customer stayed.
# - No churn customers are about 73%.
# - Churn customers are about 27%.
# - The dataset is imbalanced.
# - Accuracy alone may be misleading because most customers did not churn.
# - `TotalCharges` needed conversion from object to numeric.

# %%
numeroic_cols = df.select_dtypes(include=["int", "float64"]).columns
numeroic_cols
# Out:
# Index(['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges'], dtype='object')

# %%
df.groupby("Churn")[numeroic_cols].mean()
# Out:
#        SeniorCitizen     tenure  MonthlyCharges  TotalCharges
# Churn
# No          0.128721  37.569965       61.265124   2555.344141
# Yes         0.254682  17.979133       74.441332   1531.796094

# %%
df.groupby("Churn")[numeroic_cols].median()
# Out:
#        SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# Churn
# No               0.0    38.0          64.425       1683.60
# Yes              0.0    10.0          79.650        703.55

# %%
for col in ["tenure", "MonthlyCharges", "TotalCharges"]:
    df[col].hist()
    plt.title("f{col} Distribution")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()

# %%
for col in ["tenure", "MonthlyCharges","TotalCharges"]:
    df.boxplot(column=col, by="Churn")
    plt.title(f"{col} by Churn")
    plt.suptitle("")
    plt.xlabel("Churn")
    plt.ylabel(col)
    plt.show()

# %%
df["ChurnBinary"] = df["Churn"].map({"No":0, "Yes" : 1})
df.groupby("Contract")["ChurnBinary"].mean().sort_values(ascending=False)
# Out:
# Contract
# Month-to-month    0.427097
# One year          0.112695
# Two year          0.028319
# Name: ChurnBinary, dtype: float64

# %%
df.groupby("Contract")["ChurnBinary"].mean().sort_values(ascending=False).plot(kind="bar")
plt.title("Churn Rate by Contract")
plt.xlabel("Contract")
plt.ylabel("Churn Rate")
plt.show()

# %%
categorical_features = [
    "Contract",
    "InternetService",
    "PaymentMethod",
    "OnlineSecurity",
    "TechSupport"
]
for col in categorical_features:
    churn_rate = df.groupby(col)["ChurnBinary"].mean().sort_values(ascending=False)
    
    print(f"\nChurn Rate by {col}")
    display(churn_rate)
    
    churn_rate.plot(kind="bar")
    plt.title(f"Churn Rate by {col}")
    plt.xlabel(col)
    plt.ylabel("Churn Rate")
    plt.show()
# Out:
# Churn Rate by Contract
# Contract
# Month-to-month    0.427097
# One year          0.112695
# Two year          0.028319
# Name: ChurnBinary, dtype: float64
# Churn Rate by InternetService
# InternetService
# Fiber optic    0.418928
# DSL            0.189591
# No             0.074050
# Name: ChurnBinary, dtype: float64
# Churn Rate by PaymentMethod
# PaymentMethod
# Electronic check             0.452854
# Mailed check                 0.191067
# Bank transfer (automatic)    0.167098
# Credit card (automatic)      0.152431
# Name: ChurnBinary, dtype: float64
# Churn Rate by OnlineSecurity
# OnlineSecurity
# No                     0.417667
# Yes                    0.146112
# No internet service    0.074050
# Name: ChurnBinary, dtype: float64
# Churn Rate by TechSupport
# TechSupport
# No                     0.416355
# Yes                    0.151663
# No internet service    0.074050
# Name: ChurnBinary, dtype: float64
